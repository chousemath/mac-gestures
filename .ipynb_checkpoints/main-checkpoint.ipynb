# %%
from imageai.Prediction.Custom import CustomImagePrediction
import cv2
import datetime as dt
import os
import time
import pyautogui

# %%
p = CustomImagePrediction()
p.setModelTypeAsResNet()
path_to_resnet = 'ml/models/model_ex-057_acc-0.921196.h5'
path_to_models = 'ml/json/model_class.json'
p.setModelPath(path_to_resnet)
p.setJsonPath(path_to_models)
p.loadModel(num_objects=4)

# %%
# point-right
# dst = '/Volumes/TriveStorage/code/trive-image-recognition/gestures/x'
cap = cv2.VideoCapture(0)
while True:
    ret, frame = cap.read()
    fname = 'test.jpg'
    out = cv2.imwrite(fname, frame)
    predictions, probabilities = p.predictImage(fname, result_count=1)
    print(predictions[0])
    time.sleep(0.2)
    if predictions[0] == 'point-right':
        pyautogui.hotkey('ctrl', 'right')
    elif predictions[0] == 'point-left':
        pyautogui.hotkey('ctrl', 'left')
                         
cap.release()
# Out:
# point-left
# noise
# noise
# noise
# point-right
# point-right
# point-right
# point-right
# point-right
# point-right
# point-left
# point-left
# point-left
# point-left
# point-left
# point-left
# point-right
# point-right
# point-right
# point-right
# point-right
# point-right
# point-left
# point-left
# point-left
# point-left
# point-left
# point-right
# point-right
# point-right
# point-right
# point-right
# point-left
# point-left
# point-left
# point-left
# point-left
# point-left
# point-left
# point-left
# point-left
# point-left
# point-left
# point-left
# point-right
# point-right
# point-right
# point-right
# point-right
# point-left
# point-left
# point-left
# point-left
# point-left
# point-left
# point-left
# point-left
# point-left
# point-right
# point-left
# point-right
# point-left
# point-right
# point-left
# point-left
# point-left
# point-right
# point-left
# point-left
# point-left
# point-left
# point-left
# point-left
# point-left
# point-left
# point-left
# ...

# %%
cap.release()
